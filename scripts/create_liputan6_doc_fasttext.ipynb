# %%
from datetime import datetime
import numpy as np

def create_word2vec_word2idx(vector_file):
    word2vec = {}
    word2idx = {
        "_PAD": 0,
        "_UNK": 1,
    }
    idx = 2

    with open(vector_file, 'r', encoding='utf-8') as file:
        now = datetime.now()
        
        for line in file:
            try:
                line = line.strip().split()
                word = line[0]
                vector = [float(val) for val in line[1:]]

                # Store word-to-vector mapping
                word2vec[word] = vector

                # Create word-to-index mapping
                if word not in word2idx:
                    word2idx[word] = idx
                    idx += 1
            except Exception as e:
                continue

            if ( idx + 1 ) % 100000 == 0:
                print(f"processed {idx+1} lines in : {datetime.now() - now}")
                now = datetime.now()
            
    return word2vec, word2idx

# %%
vector_file = '/home/jupyter-23521027/refresh-bert/data/indo4b/fasttext.4B.id.300.epoch5.uncased.vec'
word2vec, word2idx = create_word2vec_word2idx(vector_file)
# Out:
# processed 100000 lines in : 0:00:07.976401
# processed 200000 lines in : 0:00:07.840785
# processed 300000 lines in : 0:00:07.939245
# processed 400000 lines in : 0:00:11.714102
# processed 500000 lines in : 0:00:07.842369
# processed 600000 lines in : 0:00:07.912034
# processed 700000 lines in : 0:00:08.199151
# processed 800000 lines in : 0:00:08.059702
# processed 900000 lines in : 0:00:08.793836
# processed 1000000 lines in : 0:00:08.694127
# processed 1100000 lines in : 0:00:07.842651
# processed 1200000 lines in : 0:00:07.753648
# processed 1300000 lines in : 0:00:07.812415
# processed 1400000 lines in : 0:00:07.804120
# processed 1500000 lines in : 0:00:16.303724
# processed 1600000 lines in : 0:00:07.521860
# processed 1700000 lines in : 0:00:07.515390
# processed 1800000 lines in : 0:00:07.502304
# processed 1900000 lines in : 0:00:07.547782
# processed 2000000 lines in : 0:00:07.505438
# processed 2100000 lines in : 0:00:07.655357
# processed 2200000 lines in : 0:00:07.544271
# processed 2300000 lines in : 0:00:07.675952
# processed 2400000 lines in : 0:00:07.524259
# processed 2500000 lines in : 0:00:07.611984
# processed 2600000 lines in : 0:00:08.062769
# processed 2700000 lines in : 0:00:08.230535
# processed 2800000 lines in : 0:00:25.144282
# processed 2900000 lines in : 0:00:08.237717
# processed 3000000 lines in : 0:00:08.188049
# processed 3100000 lines in : 0:00:08.224195
# processed 3200000 lines in : 0:00:08.245372
# processed 3300000 lines in : 0:00:08.296561
# processed 3400000 lines in : 0:00:08.285310
# processed 3500000 lines in : 0:00:08.306520
# processed 3600000 lines in : 0:00:08.265794
# processed 3700000 lines in : 0:00:08.195722
# processed 3800000 lines in : 0:00:08.287769
# processed 3900000 lines in : 0:00:08.266923
# processed 4000000 lines in : 0:00:08.180914
# processed 4100000 lines in : 0:00:08.280502
# processed 4200000 lines in : 0:00:08.274851

# %%
import os
import json
import pandas as pd

folder_path = '/home/jupyter-23521027/refresh-bert/data/liputan6_data/canonical/train' 

file_list = os.listdir(folder_path)
json_data_list = []
file_list = os.listdir(folder_path)

for file_name in file_list:
    file_path = os.path.join(folder_path, file_name) 

    if os.path.isfile(file_path):
        with open(file_path, 'r') as file:
            json_data = json.load(file)
            json_data_list.append(json_data)

df = pd.DataFrame(json_data_list)
df['sentences'] = df['clean_article'].apply(lambda x: [' '.join(sentence) for sentence in x])
df
# Out:
#             id                                                url  \
# 0        48951  https://www.liputan6.com/news/read/48951/polis...
# 1       124973  https://www.liputan6.com/news/read/124973/gent...
# 2       298677  https://www.liputan6.com/news/read/298677/wasp...
# 3        40569  https://www.liputan6.com/news/read/40569/imbau...
# 4       242869  https://www.liputan6.com/news/read/242869/rapa...
# ...        ...                                                ...
# 193878  164143  https://www.liputan6.com/news/read/164143/tahu...
# 193879  150247  https://www.liputan6.com/news/read/150247/mass...
# 193880  204203  https://www.liputan6.com/news/read/204203/bate...
# 193881  159188  https://www.liputan6.com/news/read/159188/peny...
# 193882   65953  https://www.liputan6.com/news/read/65953/ditem...
#
#                                             clean_article  \
# 0       [[Liputan6, ., com, ,, Lamongan, :, Tim, Inves...
# 1       [[Liputan6, ., com, ,, Depok, :, Abdul, Madjid...
# 2       [[Liputan6, ., com, ,, Bekasi, :, Aparat, Kepo...
# 3       [[Liputan6, ., com, ,, Denpasar, :, Imbauan, M...
# 4       [[Liputan6, ., com, ,, Jakarta, :, Gempa, kuat...
# ...                                                   ...
# 193878  [[Liputan6, ., com, ,, Jakarta, :, Warga, yang...
# 193879  [[Liputan6, ., com, ,, Bogor, :, Ribuan, umat,...
# 193880  [[Chelsea, melayangkan, keberatannya, kepada, ...
# 193881  [[Liputan6, ., com, ,, Denpasar, :, Kebakaran,...
# 193882  [[Liputan6, ., com, ,, Langkat, :, Tim, Search...
#
#                                             clean_summary extractive_summary  \
# 0       [[Senjata, api, dan, ratusan, butir, peluru, m...             [1, 2]
# 1       [[Genta, buatan, Abdul, Madjid, bisa, melahirk...             [0, 1]
# 2       [[Berhati-hatilah, Anda, bila, bepergian, ke, ...             [0, 5]
# 3       [[Peringatan, untuk, tidak, pergi, ke, Indones...             [5, 8]
# 4       [[Rapat, pleno, KPU, terhenti, ketika, gempa, ...             [0, 4]
# ...                                                   ...                ...
# 193878  [[Dirjen, Pajak, membuat, aturan, setiap, oran...             [2, 4]
# 193879  [[Ribuan, umat, Islam, menyerbu, vila, milik, ...             [0, 1]
# 193880  [[Ketua, Leeds, United, ,, Ken, Bates, berhasi...            [0, 13]
# 193881  [[Kebakaran, toko, sepatu, di, Denpasar, ,, Ba...             [0, 3]
# 193882  [[Tim, SAR, kembali, menemukan, satu, jenazah,...          [1, 2, 3]
#
#                                                 sentences
# 0       [Liputan6 . com , Lamongan : Tim Investigasi B...
# 1       [Liputan6 . com , Depok : Abdul Madjid punya k...
# 2       [Liputan6 . com , Bekasi : Aparat Kepolisian R...
# 3       [Liputan6 . com , Denpasar : Imbauan Menteri L...
# 4       [Liputan6 . com , Jakarta : Gempa kuat yang me...
# ...                                                   ...
# 193878  [Liputan6 . com , Jakarta : Warga yang belum m...
# 193879  [Liputan6 . com , Bogor : Ribuan umat Islam me...
# 193880  [Chelsea melayangkan keberatannya kepada Asosi...
# 193881  [Liputan6 . com , Denpasar : Kebakaran toko se...
# 193882  [Liputan6 . com , Langkat : Tim Search and Res...
#
# [193883 rows x 6 columns]

# %%
for i, row in df.iterrows():
    sentences = list(row["sentences"][:200])
    for sentence in sentences:
        for word in sentence.split():
            print(word)
            try:
                index = str(word2idx[word.lower()])
            except Exception as KeyError:
                index = str(word2idx["_UNK"])
            print(index)
            break

    break
# Out:
# Liputan6
# 71000
# S
# 1823
# Bimantoro
# 78860
# Demikian
# 452
# Dia
# 49
# Menurut
# 202

# %%
from datetime import datetime

MAX_DOC_LENGTH = 100
DATASET_SIZE = 999999
docs = []

now = datetime.now()
file = open("/home/jupyter-23521027/refresh-bert/data/preprocessed-input-directory/liputan6.training.doc" , 'w')

for i, row in df.iterrows():
    file.write(f'liputan6-{str(row["id"])}' + "\n")

    sentences = list(row["sentences"][:MAX_DOC_LENGTH])
    for sentence in sentences:
        for word in sentence.split():
            try:
                index = str(word2idx[word.lower()])
            except Exception as KeyError:
                index = str(word2idx["_UNK"])
            file.write(index + " ")
            
        file.write("\n")

    if (i + 1) % 10000 == 0:
        print(f"processing {i + 1} with time: {datetime.now() - now}")
        now = datetime.now()

    file.write("\n")
    
file.close()
# Out:
# processing 10000 with time: 0:00:02.625798
# processing 20000 with time: 0:00:02.369671
# processing 30000 with time: 0:00:02.686024
# processing 40000 with time: 0:00:02.446972
# processing 50000 with time: 0:00:02.367008
# processing 60000 with time: 0:00:02.287152
# processing 70000 with time: 0:00:02.316060
# processing 80000 with time: 0:00:02.299353
# processing 90000 with time: 0:00:02.354883
# processing 100000 with time: 0:00:02.330369
# processing 110000 with time: 0:00:02.306927
# processing 120000 with time: 0:00:02.267288
# processing 130000 with time: 0:00:02.299044
# processing 140000 with time: 0:00:02.293668
# processing 150000 with time: 0:00:02.302514
# processing 160000 with time: 0:00:02.328968
# processing 170000 with time: 0:00:02.345570
# processing 180000 with time: 0:00:02.294996
# processing 190000 with time: 0:00:02.272586

# %%
import os
import json
import pandas as pd

folder_path = '/home/jupyter-23521027/refresh-bert/data/liputan6_data/canonical/test' 

file_list = os.listdir(folder_path)
json_data_list = []
file_list = os.listdir(folder_path)

for file_name in file_list:
    file_path = os.path.join(folder_path, file_name) 

    if os.path.isfile(file_path):
        with open(file_path, 'r') as file:
            json_data = json.load(file)
            json_data_list.append(json_data)

df = pd.DataFrame(json_data_list)
df['sentences'] = df['clean_article'].apply(lambda x: [' '.join(sentence) for sentence in x])
df
# Out:
#           id                                                url  \
# 0      19962  https://www.liputan6.com/news/read/19962/gas-b...
# 1      23319  https://www.liputan6.com/news/read/23319/pelaj...
# 2      18513  https://www.liputan6.com/news/read/18513/bamba...
# 3      23951  https://www.liputan6.com/news/read/23951/bengk...
# 4      13167  https://www.liputan6.com/news/read/13167/bentr...
# ...      ...                                                ...
# 10967  15906  https://www.liputan6.com/news/read/15906/soepa...
# 10968  19241  https://www.liputan6.com/news/read/19241/golka...
# 10969  20408  https://www.liputan6.com/news/read/20408/pemer...
# 10970  26145  https://www.liputan6.com/news/read/26145/pemer...
# 10971  26102  https://www.liputan6.com/news/read/26102/eks-t...
#
#                                            clean_article  \
# 0      [[Liputan6, ., com, ,, Jakarta, :, Untuk, meme...
# 1      [[Liputan6, ., com, ,, Yogyakarta, :, Sekitar,...
# 2      [[Liputan6, ., com, ,, Jakarta, :, Ekspektasi,...
# 3      [[Liputan6, ., com, ,, Jakarta, :, Perampokan,...
# 4      [[Liputan6, ., com, ,, Jakarta, :, Bentrokan, ...
# ...                                                  ...
# 10967  [[Liputan6, ., com, ,, Jakarta, :, Ketua, DPR,...
# 10968  [[Liputan6, ., com, ,, Jakarta, :, Partai, Gol...
# 10969  [[Liputan6, ., com, ,, Jakarta, :, Pemerintah,...
# 10970  [[Liputan6, ., com, ,, Medan, :, Pemerintah, t...
# 10971  [[Liputan6, ., com, ,, Jakarta, :, Bekas, taha...
#
#                                            clean_summary extractive_summary  \
# 0      [[Pertamina, akan, menyalurkan, gas, alam, dar...             [0, 4]
# 1      [[Ratusan, siswa, Sekolah, Menangah, Umum, 6, ...             [1, 2]
# 2      [[Tim, Ekonomi, Pemerintah, yang, sedang, beru...             [0, 6]
# 3      [[Bengkel, Toyota, Astra, dan, Indomaret, di, ...             [0, 1]
# 4      [[Bentrokan, antara, mahasiswa, satu, kampus, ...             [0, 7]
# ...                                                  ...                ...
# 10967  [[Kepergian, Baharuddin, Lopa, membuat, Akbar,...             [0, 3]
# 10968  [[Ketua, Umum, DPP, Partai, Golkar, Akbar, Tan...             [2, 3]
# 10969  [[Pemerintah, akan, memberlakukan, sistem, UMR...          [1, 4, 5]
# 10970  [[Biro, perjalanan, haji, yang, menggunakan, p...             [1, 5]
# 10971  [[Forum, Eks, Tahanan, Politik, meminta, Presi...             [0, 1]
#
#                                                sentences
# 0      [Liputan6 . com , Jakarta : Untuk memenuhi ken...
# 1      [Liputan6 . com , Yogyakarta : Sekitar 700 sis...
# 2      [Liputan6 . com , Jakarta : Ekspektasi pasar y...
# 3      [Liputan6 . com , Jakarta : Perampokan bersenj...
# 4      [Liputan6 . com , Jakarta : Bentrokan antara m...
# ...                                                  ...
# 10967  [Liputan6 . com , Jakarta : Ketua DPR Akbar Ta...
# 10968  [Liputan6 . com , Jakarta : Partai Golongan Ka...
# 10969  [Liputan6 . com , Jakarta : Pemerintah berenca...
# 10970  [Liputan6 . com , Medan : Pemerintah tetap tak...
# 10971  [Liputan6 . com , Jakarta : Bekas tahanan poli...
#
# [10972 rows x 6 columns]

# %%
from datetime import datetime

MAX_DOC_LENGTH = 100
DATASET_SIZE = 999999
docs = []

now = datetime.now()
file = open("/home/jupyter-23521027/refresh-bert/data/preprocessed-input-directory/liputan6.test.doc" , 'w')

for i, row in df.iterrows():
    file.write(f'liputan6-{str(row["id"])}' + "\n")

    sentences = list(row["sentences"][:MAX_DOC_LENGTH])
    for sentence in sentences:
        for word in sentence.split():
            try:
                index = str(word2idx[word.lower()])
            except Exception as KeyError:
                index = str(word2idx["_UNK"])
            file.write(index + " ")
            
        file.write("\n")

    if (i + 1) % 10000 == 0:
        print(f"processing {i + 1} with time: {datetime.now() - now}")
        now = datetime.now()

    file.write("\n")
    
file.close()
# Out:
# processing 10000 with time: 0:00:02.115055

# %%
len(vocab_dict)
# Out:
# 4277095

# %%
import os
import json
import pandas as pd

folder_path = '/home/jupyter-23521027/refresh-bert/data/liputan6_data/canonical/dev' 

file_list = os.listdir(folder_path)
json_data_list = []
file_list = os.listdir(folder_path)

for file_name in file_list:
    file_path = os.path.join(folder_path, file_name) 

    if os.path.isfile(file_path):
        with open(file_path, 'r') as file:
            json_data = json.load(file)
            json_data_list.append(json_data)

df = pd.DataFrame(json_data_list)
df['sentences'] = df['clean_article'].apply(lambda x: [' '.join(sentence) for sentence in x])
df
# Out:
#           id                                                url  \
# 0       8279  https://www.liputan6.com/news/read/8279/enam-t...
# 1       1774  https://www.liputan6.com/news/read/1774/bantua...
# 2      11207  https://www.liputan6.com/news/read/11207/kapol...
# 3       2125  https://www.liputan6.com/news/read/2125/komnas...
# 4        421  https://www.liputan6.com/news/read/421/uang-me...
# ...      ...                                                ...
# 10967   7782  https://www.liputan6.com/news/read/7782/sri-so...
# 10968   5241  https://www.liputan6.com/news/read/5241/bi-dim...
# 10969   8517  https://www.liputan6.com/news/read/8517/komisi...
# 10970  11954  https://www.liputan6.com/news/read/11954/api-m...
# 10971  11993  https://www.liputan6.com/news/read/11993/tni-m...
#
#                                            clean_article  \
# 0      [[Liputan6, ., com, ,, Waringin, :, Kepala, Po...
# 1      [[Liputan6, ., com, ,, Kupang, :, Subsidi, dan...
# 2      [[Liputan6, ., com, ,, Jakarta, :, Kepala, Kep...
# 3      [[Liputan6, ., com, ,, Jakarta, :, Komisi, Nas...
# 4      [[Liputan6, ., com, ,, Jakarta, :, Beragam, ge...
# ...                                                  ...
# 10967  [[Liputan6, ., com, ,, Jakarta, :, Aksi, massa...
# 10968  [[Liputan6, ., com, ,, Jakarta, :, Perbankan, ...
# 10969  [[Liputan6, ., com, ,, Jakarta, :, Pengamat, p...
# 10970  [[Liputan6, ., com, ,, Jakarta, :, Puluhan, ru...
# 10971  [[Liputan6, ., com, ,, Jakarta, :, Tiga, hari,...
#
#                                            clean_summary extractive_summary  \
# 0      [[Polri, telah, meringkus, enam, tersangka, pe...             [2, 4]
# 1      [[Alokasi, dana, subsidi, BBM, bagi, masyaraka...             [0, 1]
# 2      [[Kapolri, meminta, tanggal, pelaksanaan, isti...             [1, 4]
# 3      [[Untuk, mencari, fakta, atas, Insiden, Wamena...             [0, 2]
# 4      [[Soal, money, politics, yang, mewarnai, kerus...             [1, 3]
# ...                                                  ...                ...
# 10967  [[Aksi, kekerasan, yang, akhir-akhir, ini, mar...             [0, 4]
# 10968  [[Bank, Indonesia, diminta, meninjau, kembali,...            [0, 10]
# 10969  [[Pengamat, penyiaran, lebih, setuju, bila, Ko...             [0, 1]
# 10970  [[Kobaran, api, melalap, puluhan, rumah, dan, ...             [1, 2]
# 10971  [[Pergantian, sembilan, anggota, Fraksi, TNI/P...             [1, 8]
#
#                                                sentences
# 0      [Liputan6 . com , Waringin : Kepala Polri Jend...
# 1      [Liputan6 . com , Kupang : Subsidi dana bahan ...
# 2      [Liputan6 . com , Jakarta : Kepala Kepolisian ...
# 3      [Liputan6 . com , Jakarta : Komisi Nasional Ha...
# 4      [Liputan6 . com , Jakarta : Beragam gejolak ti...
# ...                                                  ...
# 10967  [Liputan6 . com , Jakarta : Aksi massa yang ke...
# 10968  [Liputan6 . com , Jakarta : Perbankan nasional...
# 10969  [Liputan6 . com , Jakarta : Pengamat pers Atma...
# 10970  [Liputan6 . com , Jakarta : Puluhan rumah di r...
# 10971  [Liputan6 . com , Jakarta : Tiga hari menjelan...
#
# [10972 rows x 6 columns]

# %%
from datetime import datetime

MAX_DOC_LENGTH = 100
DATASET_SIZE = 999999
docs = []

now = datetime.now()
file = open("/home/jupyter-23521027/refresh-bert/data/preprocessed-input-directory/liputan6.validation.doc" , 'w')

for i, row in df.iterrows():
    file.write(f'liputan6-{str(row["id"])}' + "\n")

    sentences = list(row["sentences"][:MAX_DOC_LENGTH])
    for sentence in sentences:
        for word in sentence.split():
            try:
                index = str(word2idx[word.lower()])
            except Exception as KeyError:
                index = str(word2idx["_UNK"])
            file.write(index + " ")
            
        file.write("\n")

    if (i + 1) % 10000 == 0:
        print(f"processing {i + 1} with time: {datetime.now() - now}")
        now = datetime.now()

    file.write("\n")
    
file.close()
# Out:
# processing 10000 with time: 0:00:02.165036
