# %%
import matplotlib.pyplot as plt
import json

file_path = "/home/jupyter-23521027/refresh-bert/training_500_sbert_2sum/ROUGE.json"
# Read the JSON file and load data into a dictionary
with open(file_path, "r") as file:
    data = json.load(file)
    
# Training and Validation data
training_data = data["training_rouge_scores"]
validation_data = data["validation_rouge_scores"]

# Extract Rouge scores for training and validation
metrics = ['rouge_1_f_score', 'rouge_2_f_score', 'rouge_l_f_score']

training_scores = {metric: [data[metric] for data in training_data] for metric in metrics}
validation_scores = {metric: [data[metric] for data in validation_data] for metric in metrics}

# Epochs
epochs = range(1, len(training_data) + 1)

# Plotting
plt.figure(figsize=(36, 12))

# Rouge-1 F-score
plt.subplot(131)
plt.plot(epochs, training_scores['rouge_1_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_1_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs', fontsize=32)
plt.ylabel('Rouge-1 F-score', fontsize=32)
plt.title('Rouge-1 F-score', fontsize=32)
plt.legend()
plt.grid(True)
plt.xticks(epochs, fontsize=22)
plt.yticks(fontsize=22) 

# Rouge-2 F-score
plt.subplot(132)
plt.plot(epochs, training_scores['rouge_2_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_2_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs', fontsize=32)
plt.ylabel('Rouge-2 F-score', fontsize=32)
plt.title('Rouge-2 F-score', fontsize=32)
plt.legend(fontsize=32)
plt.grid(True)
plt.xticks(epochs, fontsize=22)
plt.yticks(fontsize=22) 

# Rouge-L F-score
plt.subplot(133)
plt.plot(epochs, training_scores['rouge_l_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_l_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs', fontsize=32)
plt.ylabel('Rouge-L F-score', fontsize=32)
plt.title('Rouge-L F-score', fontsize=32)
plt.legend()
plt.grid(True)
plt.xticks(epochs, fontsize=22)
plt.yticks(fontsize=22) 

plt.tight_layout()
plt.show()

# %%
plt.savefig('foo.png')

# %%
# !head -n 1000 /home/jupyter-23521027/refresh-bert/data/Baseline-Gold-Models/gold-liputan6-test-orgcase/13372.gold
print("\n")
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_cnn_2sum/model.ckpt.epoch-11.test-summary-topranked/13372.model
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_sbert_2sum/model.ckpt.epoch-3.test-summary-topranked/13372.model
# Out:
# Dugaan kelangkaan minyak solar di Jakarta dan sekitarnya tak terbukti .
# Berbagai stasiun pengisian bahan bakar umum di kawasan tersebut tampak belangsung normal .
#
#
# Karena itu , kendala pendistribusian solar bisa dianggap telah dilewati .
# Berdasarkan pantauan SCTV saat ini , berbagai stasiun pengisian bahan bakar umum ( SPBU ) bisa memperoleh pasokan solar sesuai kebutuhan .
#
# Liputan6 . com , Jakarta : Dugaan kelangkaan minyak solar di wilayah Jakarta , Bogor , Tangerang , dan Bekasi pada Senin ( 21/5 ) ini , tak terbukti .
# Karena itu , kendala pendistribusian solar bisa dianggap telah dilewati .

# %%
# !head -n 1000 /home/jupyter-23521027/refresh-bert/data/Baseline-Gold-Models/gold-liputan6-test-orgcase/13374.gold
print("\n")
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_cnn_2sum/model.ckpt.epoch-11.test-summary-topranked/13374.model
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_sbert_2sum/model.ckpt.epoch-3.test-summary-topranked/13374.model
# Out:
# Masyarakat Kotawaringin Timur menolak kedatangan warga Madura dan menunggu permintaan maaf dan ajakan damai .
# Hasil kesepakatan itu akan dibawa dalam Kongres Masyarakat Kalteng , Juni mendatang .
#
#
# Hal itu adalah hasil forum musyawarah masyarakat Kotawaringin Timur yang telah berakhir dan ditutup oleh Wakil Bupati Kotawaringin Timur Thamrin Noor , Ahad ( 20/5 ) .
# Keinginan warga Madura untuk kembali ke Kabupaten Kotawaringin Timur tampaknya belum dapat dilaksanakan .
#
# Liputan6 . com , Sampit : Masyarakat Kabupaten Kotawaringin Timur , Kalimantan Tengah , sepakat menunda kedatangan etnis Madura , sambil menunggu adanya permintaan maaf dan ajakan damai dari warga Madura .
# Hal itu adalah hasil forum musyawarah masyarakat Kotawaringin Timur yang telah berakhir dan ditutup oleh Wakil Bupati Kotawaringin Timur Thamrin Noor , Ahad ( 20/5 ) .

# %%
# !head -n 1000 /home/jupyter-23521027/refresh-bert/data/Baseline-Gold-Models/gold-liputan6-test-orgcase/13375.gold

# !head -n 1000 /home/jupyter-23521027/refresh-bert/data/Baseline-Gold-Models/gold-liputan6-test-orgcase/13375.gold
print("\n")
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_cnn_2sum/model.ckpt.epoch-11.test-summary-topranked/13375.model
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_sbert_2sum/model.ckpt.epoch-3.test-summary-topranked/13375.model
# Out:
# Prajogo Pangestu datang ke Kejagung untuk menyerahkan sejumlah dokumen , berkaitan dugaan korupsi pada proyek HTI .
# Diduga , Prayogo telah melakukan mark up dalam penggunaan dana reboisasi .
#
#
# Demikian diutarakan kuasa hukum Prajogo , Deni Kailimang di Jakarta , Senin ( 21/5 ) .
# Deni mengatakan , kedatangan Prajogo itu adalah yang kedua kalinya setelah memenuhi panggilan Kejagung untuk memberikan keterangan , beberapa waktu silam .
#
# Liputan6 . com , Jakarta : Pengusaha nasional Prajogo Pangestu menyerahkan sejumlah dokumen kepada Kejaksaan Agung , berkaitan dugaan korupsi pada proyek hutan tanaman industri ( HTI ) di Provinsi Sumatra Selatan .
# Demikian diutarakan kuasa hukum Prajogo , Deni Kailimang di Jakarta , Senin ( 21/5 ) .

# %%
# !head -n 1000 /home/jupyter-23521027/refresh-bert/data/Baseline-Gold-Models/gold-liputan6-test-orgcase/13376.gold
print("\n")
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_cnn_2sum/model.ckpt.epoch-11.test-summary-topranked/13376.model
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_sbert_2sum/model.ckpt.epoch-3.test-summary-topranked/13376.model
# Out:
# Mantan Sekretaris Jenderal Departemen Kehutanan Suripto mengajukan SP3 .
# Pihak kuasa hukum Suripto menganggap penyidik tak memiliki bukti permulaan menuding kliennya .
#
#
# Permohonan tersebut diajukan kuasa hukum Suripto , Efendi Saman , kepada Kepolisian Daerah Metro Jaya di Jakarta , Senin ( 21/5 ) pagi .
# Menurut Efendi , kliennya menganggap proses penyidikan tersebut tak berdasarkan hukum .
#
# Permohonan tersebut diajukan kuasa hukum Suripto , Efendi Saman , kepada Kepolisian Daerah Metro Jaya di Jakarta , Senin ( 21/5 ) pagi .
# Menurut Efendi , kliennya menganggap proses penyidikan tersebut tak berdasarkan hukum .

# %%
# !head -n 1000 /home/jupyter-23521027/refresh-bert/data/Baseline-Gold-Models/gold-liputan6-test-orgcase/13377.gold
print("\n")
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_cnn_2sum/model.ckpt.epoch-11.test-summary-topranked/13377.model
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_500_sbert_2sum/model.ckpt.epoch-3.test-summary-topranked/13377.model
# Out:
# Sekitar 300 orang memperingati kejatuhan Soeharto di Tugu Proklamasi , Jakarta Pusat .
# Peringatan kejatuhan mantan penguasa Orde Baru itu tidak semeriah detik-detik kejatuhannya tiga tahun silam .
#
#
# Dalam aksi yang dipusatkan di Tugu Proklamasi , Jakarta Pusat , Ketua PRD Budiman Sujatmiko dalam orasinya menyatakan di masa transisi demokrasi seperti sekarang ini , kekuatan lama terus melakukan konsolidasi .
# Budiman menuding kekerasan yang terjadi belakangan ini didalangi kekuatan konservatif yang antidemokrasi dan hak asasi manusia .
#
# Liputan6 . com , Jakarta : Sekitar 300 orang dari berbagai elemen di antaranya Partai Rakyat Demokratik , Wahana Lingkungan Hidup Indonesia , dan Perserikatan Solidaritas Perempuan memperingati lengsernya Presiden Soeharto , Senin ( 21/5 ) .
# ...

# %%
import os
import pandas as pd

def get_tokens(sentence):
    return sentence.split()

def process_folder(folder_path, folder_name):
    file_data = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r') as file:
            content = file.read()
            sentences = content.splitlines()
            tokens_list = [get_tokens(sentence) for sentence in sentences if sentence.strip()]
            token_count = sum(len(tokens) for tokens in tokens_list)
            token_count
            file_data.append({
                'File': filename,
                'Token Count': token_count,
                'Folder': folder_name,
                'Sentences': sentences,
                'Tokens': tokens_list
            })
    return file_data


folder_gold_path = "/home/jupyter-23521027/refresh-bert/data/Baseline-Gold-Models/gold-liputan6-test-orgcase"
folder_A_path = "/home/jupyter-23521027/refresh-bert/training_500_cnn_2sum/model.ckpt.epoch-11.test-summary-topranked"
folder_B_path = "/home/jupyter-23521027/refresh-bert/training_500_sbert_2sum/model.ckpt.epoch-3.test-summary-topranked"

data_gold = process_folder(folder_gold_path, 'gold')
data_A = process_folder(folder_A_path, 'A')
data_B = process_folder(folder_B_path, 'B')

# Create dataframes for Folder A and Folder B
df_gold = pd.DataFrame(data_gold)
df_A = pd.DataFrame(data_A)
df_B = pd.DataFrame(data_B)

# Concatenate both dataframes to get the final comparison dataframe
df_combined = pd.concat([df_gold, df_A, df_B], ignore_index=True)

# Group by the 'Folder' column and calculate the mean for each group
summary_by_folder = df_combined.groupby('Folder')['Token Count'].agg(['mean', 'median'])

print(summary_by_folder)
# Out:
#              mean  median
# Folder
# A       37.051312    36.0
# B       41.979402    41.0
# gold    26.207528    26.0

# %%
df_combined
# Out:
#               File  Token Count Folder  \
# 0       22924.gold           28   gold
# 1       19901.gold           32   gold
# 2       22025.gold           29   gold
# 3       24358.gold           24   gold
# 4       18161.gold           27   gold
# ...            ...          ...    ...
# 32911  15065.model           38      B
# 32912  21811.model           31      B
# 32913  16974.model           46      B
# 32914  19143.model           44      B
# 32915  18890.model           54      B
#
#                                                Sentences  \
# 0      [Pergantian antarangkatan untuk posisi Panglim...
# 1      [Perampok gaji karyawan PT Great River yang me...
# 2      [Tindak kekerasan dalam keluarga yang dialami ...
# 3      [Empat kabupaten di Jambi masih mengalami kela...
# 4      [Mantan Ketua Umum DPP PKB Matori Abdul Djalil...
# ...                                                  ...
# 32911  [Karena itu , para peternak mengharapkan pemer...
# ...

# %%
import os
import json
import pandas as pd

folder_path = '/home/jupyter-23521027/refresh-bert/data/liputan6_data/canonical/test' 

file_list = os.listdir(folder_path)
json_data_list = []
file_list = os.listdir(folder_path)

for file_name in file_list:
    file_path = os.path.join(folder_path, file_name) 

    if os.path.isfile(file_path):
        with open(file_path, 'r') as file:
            json_data = json.load(file)
            json_data_list.append(json_data)

df = pd.DataFrame(json_data_list)

# %%
df
# Out:
#           id                                                url  \
# 0      19962  https://www.liputan6.com/news/read/19962/gas-b...
# 1      23319  https://www.liputan6.com/news/read/23319/pelaj...
# 2      18513  https://www.liputan6.com/news/read/18513/bamba...
# 3      23951  https://www.liputan6.com/news/read/23951/bengk...
# 4      13167  https://www.liputan6.com/news/read/13167/bentr...
# ...      ...                                                ...
# 10967  15906  https://www.liputan6.com/news/read/15906/soepa...
# 10968  19241  https://www.liputan6.com/news/read/19241/golka...
# 10969  20408  https://www.liputan6.com/news/read/20408/pemer...
# 10970  26145  https://www.liputan6.com/news/read/26145/pemer...
# 10971  26102  https://www.liputan6.com/news/read/26102/eks-t...
#
#                                            clean_article  \
# 0      [[Liputan6, ., com, ,, Jakarta, :, Untuk, meme...
# 1      [[Liputan6, ., com, ,, Yogyakarta, :, Sekitar,...
# ...

# %%
import pandas as pd

def is_sublist(sublist, full_list):
    n = len(sublist)
    return any((sublist == full_list[i:i + n]) for i in range(len(full_list) - n + 1))

sent_indices = []  # Initialize an empty list for the Sentence Indices column

# Loop through each row in df_combined
for index, row in df_combined.iterrows():
    sentence_indices = []  # Initialize an empty list to store the indices for the current row
    for i in range(len(df)):
        if is_sublist(row['Tokens'], df['clean_article'].iloc[i]):
            sentence_indices.append(i)
    sent_indices.append(sentence_indices)

    # Print progress for every 1000 rows
    if (index + 1) % 100 == 0:
        print(f"Processed {index + 1} rows out of {len(df_combined)}")

df_combined['Sentence Indices'] = sent_indices
print(df_combined)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-c1d6daf81bcb> in <module>
#      11     sentence_indices = []  # Initialize an empty list to store the indices for the current row
#      12     for i in range(len(df)):
# ---> 13         if is_sublist(row['Tokens'], df['clean_article'].iloc[i]):
#      14             sentence_indices.append(i)
#      15     sent_indices.append(sentence_indices)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import matplotlib.pyplot as plt

all_sentence_indices = [index for sublist in df_combined['Sentence Indices'] for index in sublist]

# Plot the histogram
plt.hist(all_sentence_indices, bins='auto', edgecolor='k')
plt.xlabel('Sentence Indices')
plt.ylabel('Frequency')
plt.title('Distribution of Sentence Indices')
plt.grid(True)
plt.show()
