_2_f_score': 0.09414, 'rouge_l_f_score': 0.22422}, {'rouge_1_f_score': 0.25412, 'rouge_2_f_score': 0.10186, 'rouge_l_f_score': 0.23548}, {'rouge_1_f_score': 0.23649, 'rouge_2_f_score': 0.0889, 'rouge_l_f_score': 0.219}, {'rouge_1_f_score': 0.24645, 'rouge_2_f_score': 0.09738, 'rouge_l_f_score': 0.22858}, {'rouge_1_f_score': 0.2318, 'rouge_2_f_score': 0.08862, 'rouge_l_f_score': 0.21512}, {'rouge_1_f_score': 0.23224, 'rouge_2_f_score': 0.089, 'rouge_l_f_score': 0.21474}, {'rouge_1_f_score': 0.24707, 'rouge_2_f_score': 0.09878, 'rouge_l_f_score': 0.22842}, {'rouge_1_f_score': 0.2479, 'rouge_2_f_score': 0.09818, 'rouge_l_f_score': 0.22911}, {'rouge_1_f_score': 0.24564, 'rouge_2_f_score': 0.09583, 'rouge_l_f_score': 0.22789}, {'rouge_1_f_score': 0.2408, 'rouge_2_f_score': 0.09506, 'rouge_l_f_score': 0.22346}, {'rouge_1_f_score': 0.24845, 'rouge_2_f_score': 0.10107, 'rouge_l_f_score': 0.23155}, {'rouge_1_f_score': 0.2395, 'rouge_2_f_score': 0.09044, 'rouge_l_f_score': 0.22139}, {'rouge_1_f_score': 0.2414, 'rouge_2_f_score': 0.09405, 'rouge_l_f_score': 0.22293}, {'rouge_1_f_score': 0.24158, 'rouge_2_f_score': 0.09542, 'rouge_l_f_score': 0.22381}, {'rouge_1_f_score': 0.23841, 'rouge_2_f_score': 0.09133, 'rouge_l_f_score': 0.22055}, {'rouge_1_f_score': 0.24749, 'rouge_2_f_score': 0.09797, 'rouge_l_f_score': 0.22906}, {'rouge_1_f_score': 0.2478, 'rouge_2_f_score': 0.09849, 'rouge_l_f_score': 0.2297}]

# Extract Rouge scores for training and validation
metrics = ['rouge_1_f_score', 'rouge_2_f_score', 'rouge_l_f_score']

training_scores = {metric: [data[metric] for data in training_data] for metric in metrics}
validation_scores = {metric: [data[metric] for data in validation_data] for metric in metrics}

# Epochs
epochs = range(1, len(training_data) + 1)

# Plotting
plt.figure(figsize=(36, 12))

# Rouge-1 F-score
plt.subplot(131)
plt.plot(epochs, training_scores['rouge_1_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_1_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Rouge-1 F-score')
plt.title('Rouge-1 F-score')
plt.legend()
plt.grid(True)
plt.xticks(epochs)

# Rouge-2 F-score
plt.subplot(132)
plt.plot(epochs, training_scores['rouge_2_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_2_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Rouge-2 F-score')
plt.title('Rouge-2 F-score')
plt.legend()
plt.grid(True)
plt.xticks(epochs)

# Rouge-L F-score
plt.subplot(133)
plt.plot(epochs, training_scores['rouge_l_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_l_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Rouge-L F-score')
plt.title('Rouge-L F-score')
plt.legend()
plt.grid(True)
plt.xticks(epochs)

plt.tight_layout()
plt.show()
