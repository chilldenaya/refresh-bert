_f_score': 0.24827}, {'rouge_1_f_score': 0.26664, 'rouge_2_f_score': 0.11353, 'rouge_l_f_score': 0.24915}, {'rouge_1_f_score': 0.26423, 'rouge_2_f_score': 0.11114, 'rouge_l_f_score': 0.24734}, {'rouge_1_f_score': 0.26578, 'rouge_2_f_score': 0.11197, 'rouge_l_f_score': 0.24827}, {'rouge_1_f_score': 0.26664, 'rouge_2_f_score': 0.11353, 'rouge_l_f_score': 0.24915}, {'rouge_1_f_score': 0.26569, 'rouge_2_f_score': 0.11195, 'rouge_l_f_score': 0.24818}, {'rouge_1_f_score': 0.25982, 'rouge_2_f_score': 0.10682, 'rouge_l_f_score': 0.24264}, {'rouge_1_f_score': 0.26664, 'rouge_2_f_score': 0.11353, 'rouge_l_f_score': 0.24915}, {'rouge_1_f_score': 0.26664, 'rouge_2_f_score': 0.11353, 'rouge_l_f_score': 0.24915}, {'rouge_1_f_score': 0.26664, 'rouge_2_f_score': 0.11353, 'rouge_l_f_score': 0.24915}, {'rouge_1_f_score': 0.26664, 'rouge_2_f_score': 0.11353, 'rouge_l_f_score': 0.24915}]

# Extract Rouge scores for training and validation
metrics = ['rouge_1_f_score', 'rouge_2_f_score', 'rouge_l_f_score']

training_scores = {metric: [data[metric] for data in training_data] for metric in metrics}
validation_scores = {metric: [data[metric] for data in validation_data] for metric in metrics}

# Epochs
epochs = range(1, len(training_data) + 1)

# Plotting
plt.figure(figsize=(36, 12))

# Rouge-1 F-score
plt.subplot(131)
plt.plot(epochs, training_scores['rouge_1_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_1_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Rouge-1 F-score')
plt.title('Rouge-1 F-score')
plt.legend()
plt.grid(True)
plt.xticks(epochs)

# Rouge-2 F-score
plt.subplot(132)
plt.plot(epochs, training_scores['rouge_2_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_2_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Rouge-2 F-score')
plt.title('Rouge-2 F-score')
plt.legend()
plt.grid(True)
plt.xticks(epochs)

# Rouge-L F-score
plt.subplot(133)
plt.plot(epochs, training_scores['rouge_l_f_score'], label='Training', marker='o')
plt.plot(epochs, validation_scores['rouge_l_f_score'], label='Validation', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Rouge-L F-score')
plt.title('Rouge-L F-score')
plt.legend()
plt.grid(True)
plt.xticks(epochs)

plt.tight_layout()
plt.show()

# %%
plt.savefig('foo.png')

# %%
# !head -n 1000 /home/jupyter-23521027/refresh-bert/training_all_sbert2/model.ckpt.epoch-1.test-summary-topranked/13370.model
# Out:
# Gelagat Matori lebih memihak Mega untuk menjadi presiden sudah terlihat sejak Sidang Umum MPR 1999 .
# Penegasan tersebut disampaikan Ketua Umum Pengurus Besar Nahdlatul Ulama Hasyim Muzadi ketika berceramah dalam Forum Silaturahmi Ulama se-Jawa Tengah di Pondok Pesantren Tegal Rejo Magelang , Senin ( 21/5 ) .
# Muzadi mengaku tak terkejut dengan sikap Matori itu .

# %%
# !head -n 1000 /home/jupyter-23521027/refresh-bert/data/Baseline-Gold-Models/gold-liputan6-test-orgcase/13370.gold
# Out:
# Matori Abdul Djalil lebih mendukung Megawati Sukarnoputri menjadi presiden daripada Abdurrahman Wahid .
# Pengurus Besar Nahdlatul Ulama mengaku tak kaget dengan sikap Matori itu .

# %%
13024 + 13537
# Out:
# 26562
